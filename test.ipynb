# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
figure = plt.figure(figsize=(19.2, 10.8))
text_axes = figure.add_axes([0.0, 0.0, 1.0, 1.0])
text_axes.axis("off")
figure.set_facecolor((0.0, 0.0, 0.0))
text_axes.text(0.5,0,s="I have seen things you people would not believe", fontsize=84, style="oblique", ha="center", va="bottom", wrap=True, color="white");

# %%
alpha_array = np.linspace(0,1,20)

# %%
np.power(alpha_array,5)
# Out:
# array([0.00000000e+00, 4.03861073e-07, 1.29235543e-05, 9.81382408e-05,
#        4.13553739e-04, 1.26206585e-03, 3.14042371e-03, 6.78769306e-03,
#        1.32337197e-02, 2.38475925e-02, 4.03861073e-02, 6.50422297e-02,
#        1.00493559e-01, 1.49950790e-01, 2.17206178e-01, 3.06682003e-01,
#        4.23479029e-01, 5.73424972e-01, 7.63122961e-01, 1.00000000e+00])

# %%
for alpha in alpha_array:
    print(alpha)
# Out:
# 0.0
# 0.05263157894736842
# 0.10526315789473684
# 0.15789473684210525
# 0.21052631578947367
# 0.2631578947368421
# 0.3157894736842105
# 0.3684210526315789
# 0.42105263157894735
# 0.47368421052631576
# 0.5263157894736842
# 0.5789473684210527
# 0.631578947368421
# 0.6842105263157894
# 0.7368421052631579
# 0.7894736842105263
# 0.8421052631578947
# 0.894736842105263
# 0.9473684210526315
# 1.0

# %%
"I have seen things you people would not believe".split()
# Out:
# ['I', 'have', 'seen', 'things', 'you', 'people', 'would', 'not', 'believe']

# %%
"I have seen things you people would not believe".find(" ", 0)
# Out:
# 1
